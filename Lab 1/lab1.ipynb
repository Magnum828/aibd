# %% [markdown]
# Michał Hesek, 406399, grupa 4
# AiBD - lab 1

# %% [markdown]
# Zadanie 1
#
# Korzystając z virtual environment zainstalowałem wymagane pakiety.
#
# ![](screen1.png)
# ![](screen2.png)
# ![](screen3.png)

# %% [markdown]
# Zadanie 2
# Stworzyłem repozytorium w serwisie GitHub, synchronizuję je z folderem projektu korzystając z integracji w programie PyCharm.
#
# ![](screen4.png)
#
# https://github.com/Magnum828/aibd

# %% [markdown]
# Zadanie 3
#
# Definiuję funkcję $x^2 + 5$ a następnie wyświetlam jej wykresy w poszczególnych przedziałach poprzez pakiet matplotlib.

# %%
import numpy as np
import matplotlib.pyplot as plt


def f(x):
    return x**2 + 5

x1 = np.linspace(-1,1)
y1 = f(x1)

x2 = np.linspace(-6,6)
y2 = f(x2)

x3 = np.linspace(0,5)
y3 = f(x3)

plt.plot(x1, y1)
plt.title('x>-1 oraz x<1')
plt.xlabel('oś x')
plt.ylabel('oś y')
plt.show()

plt.plot(x2, y2)
plt.title('x>-6 oraz x<6')
plt.xlabel('oś x')
plt.ylabel('oś y')
plt.show()

plt.plot(x3, y3)
plt.title('x>0 oraz x<5')
plt.xlabel('oś x')
plt.ylabel('oś y')
# Out:
# Text(0, 0.5, 'oś y')
